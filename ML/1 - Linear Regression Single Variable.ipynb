# %% [markdown]
# <h2 style="color:green" align="center">Machine Learning With Python: Linear Regression With One Variable</h2>

# %% [markdown]
# <h3 style="color:purple">Sample problem of predicting home price in monroe, new jersey (USA)</h3>

# %% [markdown]
# Below table represents current home prices in monroe township based on square feet area, new jersey

# %% [markdown]
# <img src="https://github.com/codebasics/py/raw/3a2cdbec125f53169325d1f2faa0de4866ad7320/ML/1_linear_reg/homepricetable.JPG" style="width:370px;height:250px">

# %% [markdown]
# **Problem Statement**: Given above data build a machine learning model that can predict home prices based on square feet area

# %% [markdown]
# You can represent values in above table as a scatter plot (values are shown in red markers). After that one can draw a straight line that best fits values on chart.

# %% [markdown]
# <img src="https://github.com/codebasics/py/raw/3a2cdbec125f53169325d1f2faa0de4866ad7320/ML/1_linear_reg/scatterplot.JPG" style="width:600px;height:370px">

# %% [markdown]
# You can draw multiple lines like this but we choose the one where total sum of error is minimum

# %% [markdown]
# <img src="https://github.com/codebasics/py/raw/3a2cdbec125f53169325d1f2faa0de4866ad7320/ML/1_linear_reg/equation.PNG" style="width:600px;height:370px" >

# %% [markdown]
# You might remember about linear equation from your high school days math class. Home prices can be presented as following equation,
#
# **home price = m * (area) + b**
#
# Generic form of same equation is,

# %% [markdown]
# <img src="https://github.com/codebasics/py/raw/3a2cdbec125f53169325d1f2faa0de4866ad7320/ML/1_linear_reg/linear_equation.png" >

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../DataSets/homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.title("area vs price", fontsize=20)
plt.xlabel('area', fontsize=15)
plt.ylabel('price', fontsize=15)
plt.scatter(df.area,df.price, color='red', marker='+')
plt.show()

# %%
new_df = df.drop('price', axis='columns')
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price = df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(new_df, price)
# Out:
# LinearRegression()

# %% [markdown]
# **(1) Predict price of a home with area = 3300 sqr ft**

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# **Y = m * X + b (m is coefficient and b is intercept)**

# %%
3300*135.78767123 + 180616.43835616432
# Out:
# 628715.7534151643

# %% [markdown]
# **(1) Predict price of a home with area = 5000 sqr ft**

# %%
reg.predict([[5000]])
# Out:
# array([859554.79452055])

# %% [markdown]
# <h3 style="color:purple">Generate CSV file with list of home price predictions</h3>

# %%
area_df = pd.read_csv("areas.csv")
area_df.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = reg.predict(area_df)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
area_df['prices'] = p
area_df
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
area_df.to_csv("prediction.csv")
