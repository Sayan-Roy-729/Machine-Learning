# %% [markdown]
# # Seaborn
# ## What is Seaborn?
# - Seaborn is a Python library for data visualization build on top of the matplotlib python library.
# - Use for statistical graphics

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
days = [i for i in range(1, 16)]
temperature = [36.6, 37, 37.7, 39, 40.1, 43, 43.4, 45, 45.6, 40.1, 44, 45, 46.8, 47, 47.6]

temp_df = pd.DataFrame({"days": days, "temperature":temperature})
sns.lineplot(x="days", y="temperature", data=temp_df)
plt.show()

# %%
tips_df = sns.load_dataset("tips")
print("Shape: ", tips_df.shape)
tips_df.head()
# Out:
# Shape:  (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(x="total_bill", y="tip", data=tips_df)
plt.show()

# %%
sns.lineplot(x="tip", y="total_bill", data=tips_df)
plt.show()

# %%
sns.lineplot(x="size", y="total_bill", data=tips_df)
plt.show()

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(16, 9))
# palette is color map
sns.lineplot(x='size', y='total_bill', data=tips_df, hue='sex', style="sex", palette="twilight", dashes=False, 
             markers=["o", "<"], legend="full")
plt.xlabel("Size", fontsize=15)
plt.ylabel("Total Bill", fontsize=15)
plt.title("Line Plot", fontsize=20)
plt.show()

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(16, 9))
# palette is color map
sns.lineplot(x='size', y='total_bill', data=tips_df, hue='day', style="day", palette="twilight", dashes=False, 
             markers=["o", "<", ">", "^"], legend="full")
plt.xlabel("Size", fontsize=15)
plt.ylabel("Total Bill", fontsize=15)
plt.title("Line Plot", fontsize=20)
plt.show()
